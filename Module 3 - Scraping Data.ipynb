# %%
# Most straight-forward way to import a library in Python
import requests

# BeautifulSoup is a module inside the "bs4" library, we only import the BeautifulSoup module
from bs4 import BeautifulSoup

# We import pandas but give the library a shortcut alias "pd" since we will call its functions so much
import pandas as pd

from nltk.corpus import stopwords

# %% [markdown]
# ## Compare Some Democratic Presidential Runners Views on Healthcare to Trump
# ### Which candidate has the closest relationship to Trumps health care priorities?
# ### What are some limitations to this analysis?
# ### How might these limitations effect the scores?

# %%
warren_raw = requests.get('https://elizabethwarren.com/plans/health-care').text

warren_soup = BeautifulSoup(warren_raw,'html.parser')

# %%
warren_groups = warren_soup.find_all('div',{'id':"react-application"})

# How many tags in total?
print(len(warren_groups))

# Inspect the first one
warren_groups[0]
# Out:
# 1
# ...

# %%
warren_groups[0].find_all('p',{'class':"RichTextBlocks__Paragraph-sc-190n2pz-0 ddscZi"})
# Out:
# [<p class="RichTextBlocks__Paragraph-sc-190n2pz-0 ddscZi">When Elizabeth was in middle school, her father had a heart attack. He was out of work for a long time, and the bills piled up. They lost their family station wagon, and they came about an inch away from losing their house. </p>,
#  <p class="RichTextBlocks__Paragraph-sc-190n2pz-0 ddscZi">Years later, as a bankruptcy law professor, Elizabeth studied why working families were going broke. Her research showed that most people who filed for bankruptcy looked a lot like her family – most were solidly middle class, and about half had filed for bankruptcy in the aftermath of a serious medical problem. And here was the kicker: about three-quarters of them had health insurance, but it just wasn’t enough.</p>,
# ...

# %%
warren_hc = []
    
for p in warren_groups[0].find_all('p',{'class':"RichTextBlocks__Paragraph-sc-190n2pz-0 ddscZi"}):
    warren_hc.append(p.text)

# %%
warren_hc
# Out:
# ['When Elizabeth was in middle school, her father had a heart attack. He was out of work for a long time, and the bills piled up. They lost their family station wagon, and they came about an inch away from losing their house.\xa0',
#  'Years later, as a bankruptcy law professor, Elizabeth studied why working families were going broke. Her research showed that most people who filed for bankruptcy looked a lot like her family – most were solidly middle class, and about half had filed for bankruptcy in the aftermath of a serious medical problem. And here was the kicker: about three-quarters of them had health insurance, but it just wasn’t enough.',
#  'The Affordable Care Act made massive strides in expanding access to health insurance coverage, and we must defend Medicaid and the Affordable Care Act against Republican attempts to rip health care away from people. But it’s time for the next step.',
# ...

# %%
warren_hc[4].lower().split(' '), warren_hc[5].lower().split(' '), warren_hc[6].lower().split(' '),warren_hc[7].lower().split(' '), warren_hc[8].lower().split(' ')
# Out:
# (['the',
#   'basic',
#   'business',
#   'model',
#   'of',
#   'an',
#   'insurance',
#   'company',
#   'is',
#   'to',
#   'take',
#   'in',
#   'as',
#   'much',
#   'money',
#   'as',
#   'you',
#   'can',
#   'in',
#   'premiums',
#   'and',
#   'paying',
#   'out',
#   'as',
#   'little',
#   'as',
#   'possible',
#   'in',
#   'health',
#   'care',
#   'coverage.'],
#  ['that',
#   'leaves',
#   'families',
#   'with',
#   'rising',
#   'premiums,',
#   'high',
#   'deductibles,',
#   'and',
#   'fighting',
#   'with',
#   'insurance',
#   'companies',
#   'to',
#   'try',
#   'to',
#   'get',
#   'the',
#   'health',
#   'care',
#   'that',
#   'their',
#   'doctors',
#   'say',
#   'they',
#   'and',
#   'their',
#   'children',
#   'need.'],
#  ['insurers',
#   'protecting',
#   'their',
#   'bottom',
#   'lines',
#   'restrict',
#   'your',
#   'networks',
#   'of',
#   'providers',
#   'and',
#   'stand',
#   'in',
#   'the',
#   'way',
#   'when',
#   'you',
# ...

# %%
# set stopwords using NLTK

sw = set(stopwords.words('english'))

# %%
# Create list of words in Warren's health care article 
# Format words to all be lower-case ".lower()"
# Also format words to be split on spaces ".split(' ')"
# Was tricky looping through warren_hc for some reason so I had to add words in kind of a janky way.

# %%
warren_hc_list = []

# %%
for word in warren_hc[4].lower().split(' '):
    if word not in sw:
        warren_hc_list.append(word)
for word in warren_hc[5].lower().split(' '):
    if word not in sw:
        warren_hc_list.append(word)
for word in warren_hc[6].lower().split(' '):
    if word not in sw:
        warren_hc_list.append(word)
for word in warren_hc[7].lower().split(' '):
    if word not in sw:
        warren_hc_list.append(word)

# %%
for word in warren_hc[8].lower().split(' '):
    if word not in sw:
        warren_hc_list.append(word)
for word in warren_hc[9].lower().split(' '):
    if word not in sw:
        warren_hc_list.append(word)
for word in warren_hc[10].lower().split(' '):
    if word not in sw:
        warren_hc_list.append(word)
for word in warren_hc[11].lower().split(' '):
    if word not in sw:
        warren_hc_list.append(word)
for word in warren_hc[12].lower().split(' '):
    if word not in sw:
        warren_hc_list.append(word)
for word in warren_hc[13].lower().split(' '):
    if word not in sw:
        warren_hc_list.append(word)
for word in warren_hc[14].lower().split(' '):
    if word not in sw:
        warren_hc_list.append(word)
for word in warren_hc[15].lower().split(' '):
    if word not in sw:
        warren_hc_list.append(word)
for word in warren_hc[16].lower().split(' '):
    if word not in sw:
        warren_hc_list.append(word)
for word in warren_hc[17].lower().split(' '):
    if word not in sw:
        warren_hc_list.append(word)
for word in warren_hc[18].lower().split(' '):
    if word not in sw:
        warren_hc_list.append(word)
for word in warren_hc[19].lower().split(' '):
    if word not in sw:
        warren_hc_list.append(word)

# %%
warren_hc_list
# Out:
# ['basic',
#  'business',
#  'model',
#  'insurance',
#  'company',
#  'take',
#  'much',
#  'money',
#  'premiums',
#  'paying',
#  'little',
#  'possible',
#  'health',
#  'care',
#  'coverage.',
#  'leaves',
#  'families',
#  'rising',
#  'premiums,',
#  'high',
#  'deductibles,',
#  'fighting',
#  'insurance',
#  'companies',
#  'try',
#  'get',
#  'health',
#  'care',
#  'doctors',
#  'say',
#  'children',
#  'need.',
#  'insurers',
#  'protecting',
#  'bottom',
#  'lines',
#  'restrict',
#  'networks',
#  'providers',
#  'stand',
#  'way',
#  'want',
#  'see',
#  'doctor',
#  'need',
#  'see',
#  'specialist',
#  'without',
#  'going',
#  'broke.\xa0',
#  'medicare',
#  'solves',
#  'problems.',
#  'everyone',
#  'see',
#  'doctor',
#  'need.',
#  'nobody',
#  'goes',
#  'broke.',
#  'doctor',
#  'gets',
#  'paid',
#  'medicare',
#  'instead',
#  'fighting',
#  'insurance',
#  'company.\xa0\xa0',
#  'every',
#  'american',
#  'able',
#  'get',
#  'care',
#  'need',
#  'need',
# ...

# %%
# Turn Warren_hc_list into a set
# Sets are unindexed, unordered, have non-repeating items, and make it easy to access items

# %%
set (warren_hc_list)
# Out:
# {'$100',
#  '$25',
#  '--',
#  '15',
#  '15,000',
#  '1980s,',
#  '1990,',
#  '2017,',
#  'able',
#  'abuse',
#  'access',
#  'accountable',
#  'across',
#  'act',
#  'act,',
#  'addiction',
#  'addictive',
#  'addition',
#  'adequate',
#  'afford',
#  'affordable',
#  'affordable,',
#  'afloat.\xa0',
#  'aggressively',
#  'alike',
#  'all.',
#  'allow',
#  'also',
#  'american',
#  'americans',
#  'antitrust',
#  'apprenticeship',
#  'areas,',
#  'areas.',
#  'array',
#  'barriers',
#  'basic',
#  'behavioral',
#  'benefits',
#  'billion',
#  'bottom',
#  'bring',
#  'broke.',
#  'broke.\xa0',
#  'build',
#  'business',
#  'can’t',
#  'cap',
#  'capital',
#  'care',
#  'care,',
#  'cases',
#  'centers',
#  'charge',
#  'children',
#  'citizens',
#  'close',
#  'colleges,',
#  'combat',
#  'communities',
#  'communities.',
#  'community',
#  'community.\xa0',
#  'companies',
#  'companies.',
#  'company',
#  'company.\xa0\xa0',
#  'competition',
#  'compliance',
#  'confront',
# ...

# %%
print(len(warren_hc_list))
print(len(set(warren_hc_list)))
# Out:
# 554
# 382

# %% [markdown]
# ## Bernie Sanders

# %%
# Similar process as Warren for other Candidates

# %%
bernie_raw = requests.get('https://berniesanders.com/issues/medicare-for-all/').text

bernie_soup = BeautifulSoup(bernie_raw,'html.parser')

# %%
# Get all the groups that have a <> tag
bernie_groups = bernie_soup.find_all('section',{'class':'my-3'})

# How many tags in total?
print(len(bernie_groups))

# Inspect the first one
bernie_groups[0]
# Out:
# 1
# <section class="my-3">
# <div class="container">
# <div class="row">
# <div class="col-lg-8 offset-lg-1 col-xs-12">
# <div class="issue-body">
# <h2 class="mb-3 mt-3">Details</h2>
# ...

# %%
bernie_groups[0].find_all('div',{'class':"rich-text"})
# Out:
# [<div class="rich-text"><p></p><p>Today, more than 30 million Americans still don’t have health insurance and even more are underinsured. Even for those with insurance, costs are so high that medical bills are the number one cause of bankruptcy in the United States. Incredibly, we spend significantly more of our national GDP on this inadequate health care system—far more per person than any other major country. And despite doing so, Americans have worse health outcomes and a higher infant mortality rate than countries that spend much less on health care. Our people deserve better.</p><p>We should be spending money on doctors, nurses, mental health specialists, dentists, and other professionals who provide services to people and improve their lives. We must invest in the development of new drugs and technologies that cure disease and alleviate pain—not wasting hundreds of billions of dollars a year on profiteering, huge executive compensation packages, and outrageous administrative co
# ...

# %%
bernie_hc = []
    
for p in bernie_groups[0].find_all('div',{'class':"rich-text"}):
    bernie_hc.append(p.text)

# %%
bernie_hc
# Out:
# ['Today, more than 30 million Americans still don’t have health insurance and even more are underinsured. Even for those with insurance, costs are so high that medical bills are the number one cause of bankruptcy in the United States. Incredibly, we spend significantly more of our national GDP on this inadequate health care system—far more per person than any other major country. And despite doing so, Americans have worse health outcomes and a higher infant mortality rate than countries that spend much less on health care. Our people deserve better.We should be spending money on doctors, nurses, mental health specialists, dentists, and other professionals who provide services to people and improve their lives. We must invest in the development of new drugs and technologies that cure disease and alleviate pain—not wasting hundreds of billions of dollars a year on profiteering, huge executive compensation packages, and outrageous administrative costs.The giant pharmaceutical and health
# ...

# %%
bernie_hc[0].lower().split(' ')
# Out:
# ['today,',
#  'more',
#  'than',
#  '30',
#  'million',
#  'americans',
#  'still',
#  'don’t',
#  'have',
#  'health',
#  'insurance',
#  'and',
#  'even',
#  'more',
#  'are',
#  'underinsured.',
#  'even',
#  'for',
#  'those',
#  'with',
#  'insurance,',
#  'costs',
#  'are',
#  'so',
#  'high',
#  'that',
#  'medical',
#  'bills',
#  'are',
#  'the',
#  'number',
#  'one',
#  'cause',
#  'of',
#  'bankruptcy',
#  'in',
#  'the',
#  'united',
#  'states.',
#  'incredibly,',
#  'we',
#  'spend',
#  'significantly',
#  'more',
#  'of',
#  'our',
#  'national',
#  'gdp',
#  'on',
#  'this',
#  'inadequate',
#  'health',
#  'care',
#  'system—far',
#  'more',
#  'per',
#  'person',
#  'than',
#  'any',
#  'other',
#  'major',
#  'country.',
#  'and',
#  'despite',
#  'doing',
#  'so,',
#  'americans',
#  'have',
#  'worse',
#  'health',
#  'outcomes',
#  'and',
#  'a',
#  'higher',
#  'infant',
#  'mortality',
#  'rate',
#  'than',
#  'countries',
#  'that',
#  'spend',
#  'much',
# ...

# %%
bernie_hc_list = []

# %%
for word in bernie_hc[0].lower().split(' '):
    if word not in sw:
        bernie_hc_list.append(word)

# %%
set (bernie_hc_list)
# Out:
# {'30',
#  'act,',
#  'act.allow',
#  'act.cut',
#  'administrative',
#  'affordable',
#  'alleviate',
#  'american',
#  'americans',
#  'bankruptcy',
#  'better.we',
#  'big',
#  'billions',
#  'bills',
#  'buy',
#  'canada',
#  'canada,',
#  'care',
#  'care.',
#  'cause',
#  'come',
#  'companies',
#  'compensation',
#  'costs',
#  'costs.the',
#  'countries',
#  'countries:',
#  'country',
#  'country.',
#  'cure',
#  'decades',
#  'defeat',
#  'dentists,',
#  'deserve',
#  'despite',
#  'development',
#  'disease',
#  'doctors,',
#  'dollars',
#  'don’t',
#  'drug',
#  'drugs',
#  'earth',
#  'ensure',
#  'even',
#  'every',
#  'executive',
#  'five',
#  'france,',
#  'gdp',
#  'germany,',
#  'giant',
#  'guaranteeing',
#  'half,',
#  'health',
#  'high',
#  'higher',
#  'huge',
#  'hundreds',
#  'importation',
#  'improve',
#  'inadequate',
#  'incredibly,',
#  'industrialized',
#  'infant',
#  'insurance',
#  'insurance,',
#  'invest',
#  'japan.',
#  'kingdom,',
#  'less',
# ...

# %%
print(len(bernie_hc_list))
print(len(set(bernie_hc_list)))
# Out:
# 185
# 144

# %% [markdown]
# ## Cory Booker

# %%
booker_raw = requests.get('https://corybooker.com/issues/health-care/policy-page/').text
booker_soup = BeautifulSoup(booker_raw,'html.parser')

# %%
booker_groups = booker_soup.find_all('section',{'class':'policy-section'})

# How many tags in total?
print(len(booker_groups))

# Inspect the first one
booker_groups[0]
# Out:
# 1
# <section class="policy-section">
# <h1 class="booker-module--headline">
# Bringing dignity and choice to long-term care: Cory’s plan to expand access to high-quality, affordable, long-term services and supports
# </h1>
# <div id="social-share"></div>
# ...

# %%
booker_groups[0].find_all('p')
# Out:
# [<p>Many Americans will need long-term care at some point in their lives—and many will be caregivers themselves. The need for care is only growing; by 2050, the 65-and-older population will more than <a href="https://phinational.org/wp-content/uploads/legacy/phi-home-care-workers-key-facts.pdf">double</a>, growing from 47.8 million to 88 million, while the 85-and-older population will more than triple, growing from 6.3 million to 19 million. But the costs can make care inaccessible; among Americans turning 65 this year, more than 4 in 10 will <a href="https://www.naic.org/documents/cipr_current_study_160519_ltc_insurance.pdf">spend</a> over $25,000 in long-term services and supports over the course of their lives, and 1 in 7 will spend more than $250,000. It’s not just seniors that rely on long-term support: people with disabilities under the age of 65 make up <a href="https://www.macpac.gov/wp-content/uploads/2015/01/Medicaids_Role_in_Providing_Assistance_with_Long-Term_Services_and
# ...

# %%
booker_hc = []
    
for p in booker_groups[0].find_all('p'):
    booker_hc.append(p.text)

# %%
booker_hc
# Out:
# ['Many Americans will need long-term care at some point in their lives—and many will be caregivers themselves. The need for care is only growing; by 2050, the 65-and-older population will more than double, growing from 47.8 million to 88 million, while the 85-and-older population will more than triple, growing from 6.3 million to 19 million. But the costs can make care inaccessible; among Americans turning 65 this year, more than 4 in 10 will spend over $25,000 in long-term services and supports over the course of their lives, and 1 in 7 will spend more than $250,000. It’s not just seniors that rely on long-term support: people with disabilities under the age of 65 make up 42% of recipients of Medicaid-funded long-term services and supports. And nearly 30 years after the passage of the Americans with Disabilities Act, the promise of the Act to secure liberty for people with disabilities remains unmet, in part due to a lack of access to long term services and supports.',
# ...

# %%
set(booker_hc)
# Out:
# {'At the same time, we face a shortage of care providers. The demand for direct care workers—who include certified nursing assistants employed in nursing homes and home care workers—is estimated to have grown by 30 percent from 2016 to 2026. All told, the Bureau of Labor Statistics projects there will be 7.8 million direct care job openings, including 1.4 million new positions due to rising demand. The home care workforce alone is predicted to grow by more than 40% over the same period, making it the third fastest-growing job sector in the entire country. But despite the essential role they play as caregivers, direct care workers are overwhelmingly underpaid: direct-care workers earn a median pay of $11.83 per hour and a median annual salary of just $19,100.',
# ...

# %%
booker_hc[0].lower().split(' ')
# Out:
# ['many',
#  'americans',
#  'will',
#  'need',
#  'long-term',
#  'care',
#  'at',
#  'some',
#  'point',
#  'in',
#  'their',
#  'lives—and',
#  'many',
#  'will',
#  'be',
#  'caregivers',
#  'themselves.',
#  'the',
#  'need',
#  'for',
#  'care',
#  'is',
#  'only',
#  'growing;',
#  'by',
#  '2050,',
#  'the',
#  '65-and-older',
#  'population',
#  'will',
#  'more',
#  'than',
#  'double,',
#  'growing',
#  'from',
#  '47.8',
#  'million',
#  'to',
#  '88',
#  'million,',
#  'while',
#  'the',
#  '85-and-older',
#  'population',
#  'will',
#  'more',
#  'than',
#  'triple,',
#  'growing',
#  'from',
#  '6.3',
#  'million',
#  'to',
#  '19',
#  'million.',
#  'but',
#  'the',
#  'costs',
#  'can',
#  'make',
#  'care',
#  'inaccessible;',
#  'among',
#  'americans',
#  'turning',
#  '65',
#  'this',
#  'year,',
#  'more',
#  'than',
#  '4',
#  'in',
#  '10',
#  'will',
#  'spend',
#  'over',
#  '$25,000',
#  'in',
#  'long-term',
#  'services',
#  'and',
#  'supports',
# ...

# %%
booker_hc_list = []

# %%
for word in booker_hc[0].lower().split(' '):
    if word not in sw:
        booker_hc_list.append(word)
for word in booker_hc[1].lower().split(' '):
    if word not in sw:
        booker_hc_list.append(word)
for word in booker_hc[2].lower().split(' '):
    if word not in sw:
        booker_hc_list.append(word)
for word in booker_hc[3].lower().split(' '):
    if word not in sw:
        booker_hc_list.append(word)
for word in booker_hc[4].lower().split(' '):
    if word not in sw:
        booker_hc_list.append(word)
for word in booker_hc[5].lower().split(' '):
    if word not in sw:
        booker_hc_list.append(word)
for word in booker_hc[6].lower().split(' '):
    if word not in sw:
        booker_hc_list.append(word)
for word in booker_hc[7].lower().split(' '):
    if word not in sw:
        booker_hc_list.append(word)
for word in booker_hc[8].lower().split(' '):
    if word not in sw:
        booker_hc_list.append(word)

# %%
set (booker_hc_list)
# Out:
# {'$11.83',
#  '$15',
#  '$19,100.',
#  '$2,000',
#  '$200,000',
#  '$25,000',
#  '$250,000.',
#  '$3,000',
#  '$36,541',
#  '$49,380',
#  '(approximately',
#  '(hhs)',
#  '(in',
#  '(ltss).',
#  '(or',
#  '1',
#  '1.4',
#  '10',
#  '19',
#  '2016',
#  '2026.',
#  '2050,',
#  '222%',
#  '30',
#  '300%',
#  '37%',
#  '4',
#  '40%',
#  '42%',
#  '47.8',
#  '56%',
#  '6.3',
#  '600,000.',
#  '65',
#  '65-and-older',
#  '7',
#  '7.8',
#  '85-and-older',
#  '87',
#  '87%',
#  '88',
#  'aarp,',
#  'able',
#  'access',
#  'according',
#  'across',
#  'act',
#  'act,',
#  'addition,',
#  'address',
#  'administration’s',
#  'adults',
#  'advancing',
#  'affordable',
#  'age',
#  'age.',
#  'all,',
#  'alone',
#  'also',
#  'alternatives,',
#  'american.',
#  'americans',
#  'americans.',
#  'among',
#  'and/or',
#  'annual',
#  'ask',
#  'asset',
#  'assets',
#  'assistance',
#  'assistants',
#  'back',
#  'believes',
#  'beneficiaries',
#  'benefits',
#  'benefits,',
#  'best',
#  'bias',
# ...

# %%
print(len(booker_hc_list))
print(len(set(booker_hc_list)))
# Out:
# 2470
# 395

# %% [markdown]
# ## Comparing all 3 Democrats

# %%
# Elizabeth Warren
s1 = set (warren_hc_list)

# Bernie Sanders
s2 = set (bernie_hc_list)

# Cory Booker 
s3 = set (booker_hc_list)

# Donald Trump
s4 = set (trump_hc_list)

# %%
# Intersection of all Democrats
# Intersection = all items that are in s1, s2, and s3
intersection_all = s1 & s2 & s3

# %%
intersection_all
# Out:
# {'act,',
#  'affordable',
#  'americans',
#  'care',
#  'costs',
#  'country',
#  'despite',
#  'ensure',
#  'every',
#  'health',
#  'less',
#  'medical',
#  'medicare',
#  'must',
#  'need',
#  'new',
#  'one',
#  'per',
#  'provide',
#  'services'}

# %%
len (intersection_all)
# Out:
# 20

# %%
# Union of all Democrats
# Union contains all the elements of the sets
union_all = s1 | s2 | s3

# %%
union_all
# Out:
# {'$100',
#  '$11.83',
#  '$15',
#  '$19,100.',
#  '$2,000',
#  '$200,000',
#  '$25',
#  '$25,000',
#  '$250,000.',
#  '$3,000',
#  '$36,541',
#  '$49,380',
#  '(approximately',
#  '(hhs)',
#  '(in',
#  '(ltss).',
#  '(or',
#  '--',
#  '1',
#  '1.4',
#  '10',
#  '15',
#  '15,000',
#  '19',
#  '1980s,',
#  '1990,',
#  '2016',
#  '2017,',
#  '2026.',
#  '2050,',
#  '222%',
#  '30',
#  '300%',
#  '37%',
#  '4',
#  '40%',
#  '42%',
#  '47.8',
#  '56%',
#  '6.3',
#  '600,000.',
#  '65',
#  '65-and-older',
#  '7',
#  '7.8',
#  '85-and-older',
#  '87',
#  '87%',
#  '88',
#  'aarp,',
#  'able',
#  'abuse',
#  'access',
#  'according',
#  'accountable',
#  'across',
#  'act',
#  'act,',
#  'act.allow',
#  'act.cut',
#  'addiction',
#  'addictive',
#  'addition',
#  'addition,',
#  'address',
#  'adequate',
#  'administration’s',
#  'administrative',
#  'adults',
#  'advancing',
#  'afford',
#  'affordable',
#  'affordable,',
#  'afloat.\xa0',
#  'age',
#  'age.',
#  'aggressively',
# ...

# %%
len (union_all)
# Out:
# 787

# %%
len(s1 & s2 & s3)/len(s1 | s2 | s3)
# Out:
# 0.025412960609911054

# %% [markdown]
# ## Let's Compare Warren to Bernie

# %% [markdown]
# ## Intersection

# %%
intersection_wb = s1 & s2

# %%
intersection_wb
# Out:
# {'act,',
#  'affordable',
#  'american',
#  'americans',
#  'care',
#  'companies',
#  'costs',
#  'countries',
#  'country',
#  'despite',
#  'drug',
#  'drugs',
#  'ensure',
#  'every',
#  'five',
#  'health',
#  'high',
#  'higher',
#  'insurance',
#  'invest',
#  'less',
#  'lower',
#  'medical',
#  'medicare',
#  'mental',
#  'money',
#  'much',
#  'must',
#  'national',
#  'need',
#  'negotiate',
#  'new',
#  'one',
#  'per',
#  'person',
#  'price',
#  'prices',
#  'professionals',
#  'provide',
#  'rate',
#  'services',
#  'united',
#  'year'}

# %%
len (intersection_wb)
# Out:
# 43

# %% [markdown]
# ## Union

# %%
union_wb = s1|s2

# %%
union_wb
# Out:
# {'$100',
#  '$25',
#  '--',
#  '15',
#  '15,000',
#  '1980s,',
#  '1990,',
#  '2017,',
#  '30',
#  'able',
#  'abuse',
#  'access',
#  'accountable',
#  'across',
#  'act',
#  'act,',
#  'act.allow',
#  'act.cut',
#  'addiction',
#  'addictive',
#  'addition',
#  'adequate',
#  'administrative',
#  'afford',
#  'affordable',
#  'affordable,',
#  'afloat.\xa0',
#  'aggressively',
#  'alike',
#  'all.',
#  'alleviate',
#  'allow',
#  'also',
#  'american',
#  'americans',
#  'antitrust',
#  'apprenticeship',
#  'areas,',
#  'areas.',
#  'array',
#  'bankruptcy',
#  'barriers',
#  'basic',
#  'behavioral',
#  'benefits',
#  'better.we',
#  'big',
#  'billion',
#  'billions',
#  'bills',
#  'bottom',
#  'bring',
#  'broke.',
#  'broke.\xa0',
#  'build',
#  'business',
#  'buy',
#  'canada',
#  'canada,',
#  'can’t',
#  'cap',
#  'capital',
#  'care',
#  'care,',
#  'care.',
#  'cases',
#  'cause',
#  'centers',
#  'charge',
#  'children',
#  'citizens',
#  'close',
#  'colleges,',
# ...

# %%
len (union_wb)
# Out:
# 483

# %% [markdown]
# ## Using Jaccard Similarity to find the amount of similarity of the various set lists we have created. There is a great link to explain Jaccard Similarity right here --> https://towardsdatascience.com/overview-of-text-similarity-metrics-3397c4601f50

# %% [markdown]
# ## Similarity, Warren and Bernie

# %%
# Find the "Jaccard Similarity" which is size of intersection of the set divided by total size of set. 
len(s1 & s2)/len(s1 | s2)

# return float(len(c)) / (len(s1) + len(s2) - len(c))?
# Out:
# 0.08902691511387163

# %% [markdown]
# ## Now let's look at Warren and Booker

# %%
intersection_wbook = s1 & s3

# %%
intersection_wbook
# Out:
# {'able',
#  'access',
#  'across',
#  'act',
#  'act,',
#  'affordable',
#  'also',
#  'americans',
#  'benefits',
#  'care',
#  'care,',
#  'communities',
#  'community',
#  'costs',
#  'country',
#  'current',
#  'department',
#  'despite',
#  'ensure',
#  'ensuring',
#  'essential',
#  'every',
#  'everyone',
#  'families.',
#  'federal',
#  'fight',
#  'funding',
#  'get',
#  'grow',
#  'growing',
#  'guaranteed',
#  'health',
#  'hhs',
#  'human',
#  'improving',
#  'increase',
#  'less',
#  'life',
#  'limited',
#  'make',
#  'many',
#  'medicaid',
#  'medical',
#  'medicare',
#  'meet',
#  'millions',
#  'must',
#  'need',
#  'needs',
#  'new',
#  'one',
#  'options',
#  'paid',
#  'per',
#  'percent',
#  'plan',
#  'professional',
#  'provide',
#  'providing',
#  'public',
#  'quality,',
#  'rates,',
#  'receive',
#  'required',
#  'right',
#  'rising',
#  'services',
#  'services.',
#  'shortage',
#  'standards',
#  'states',
#  'stay',
#  'support',
#  'system',
# ...

# %%
len (intersection_wbook)
# Out:
# 81

# %%
union_wbook = s1|s3

# %%
union_wbook
# Out:
# {'$100',
#  '$11.83',
#  '$15',
#  '$19,100.',
#  '$2,000',
#  '$200,000',
#  '$25',
#  '$25,000',
#  '$250,000.',
#  '$3,000',
#  '$36,541',
#  '$49,380',
#  '(approximately',
#  '(hhs)',
#  '(in',
#  '(ltss).',
#  '(or',
#  '--',
#  '1',
#  '1.4',
#  '10',
#  '15',
#  '15,000',
#  '19',
#  '1980s,',
#  '1990,',
#  '2016',
#  '2017,',
#  '2026.',
#  '2050,',
#  '222%',
#  '30',
#  '300%',
#  '37%',
#  '4',
#  '40%',
#  '42%',
#  '47.8',
#  '56%',
#  '6.3',
#  '600,000.',
#  '65',
#  '65-and-older',
#  '7',
#  '7.8',
#  '85-and-older',
#  '87',
#  '87%',
#  '88',
#  'aarp,',
#  'able',
#  'abuse',
#  'access',
#  'according',
#  'accountable',
#  'across',
#  'act',
#  'act,',
#  'addiction',
#  'addictive',
#  'addition',
#  'addition,',
#  'address',
#  'adequate',
#  'administration’s',
#  'adults',
#  'advancing',
#  'afford',
#  'affordable',
#  'affordable,',
#  'afloat.\xa0',
#  'age',
#  'age.',
#  'aggressively',
#  'alike',
#  'all,',
#  'all.',
#  'allow',
#  'alone',
# ...

# %%
len (union_wbook)
# Out:
# 696

# %%
len(s1 & s3)/len(s1 | s3)
# Out:
# 0.11637931034482758

# %%
intersection_berniebook = s2 & s3

# %%
intersection_berniebook
# Out:
# {'30',
#  'act,',
#  'affordable',
#  'americans',
#  'buy',
#  'care',
#  'care.',
#  'costs',
#  'country',
#  'country.',
#  'despite',
#  'development',
#  'ensure',
#  'even',
#  'every',
#  'health',
#  'less',
#  'median',
#  'medical',
#  'medicare',
#  'million',
#  'must',
#  'need',
#  'new',
#  'one',
#  'people',
#  'per',
#  'provide',
#  'services',
#  'spend'}

# %%
len (intersection_berniebook)
# Out:
# 30

# %%
union_berniebook = s2|s3

# %%
union_berniebook
# Out:
# {'$11.83',
#  '$15',
#  '$19,100.',
#  '$2,000',
#  '$200,000',
#  '$25,000',
#  '$250,000.',
#  '$3,000',
#  '$36,541',
#  '$49,380',
#  '(approximately',
#  '(hhs)',
#  '(in',
#  '(ltss).',
#  '(or',
#  '1',
#  '1.4',
#  '10',
#  '19',
#  '2016',
#  '2026.',
#  '2050,',
#  '222%',
#  '30',
#  '300%',
#  '37%',
#  '4',
#  '40%',
#  '42%',
#  '47.8',
#  '56%',
#  '6.3',
#  '600,000.',
#  '65',
#  '65-and-older',
#  '7',
#  '7.8',
#  '85-and-older',
#  '87',
#  '87%',
#  '88',
#  'aarp,',
#  'able',
#  'access',
#  'according',
#  'across',
#  'act',
#  'act,',
#  'act.allow',
#  'act.cut',
#  'addition,',
#  'address',
#  'administration’s',
#  'administrative',
#  'adults',
#  'advancing',
#  'affordable',
#  'age',
#  'age.',
#  'all,',
#  'alleviate',
#  'alone',
#  'also',
#  'alternatives,',
#  'american',
#  'american.',
#  'americans',
#  'americans.',
#  'among',
#  'and/or',
#  'annual',
#  'ask',
#  'asset',
#  'assets',
#  'assistance',
#  'assistants',
#  'back',
# ...

# %%
len (union_berniebook)
# Out:
# 509

# %%
len(s2 & s3)/len(s2 | s3)
# Out:
# 0.05893909626719057

# %% [markdown]
# ## Let's try to bring in Trump for fun.

# %%
trump_raw = requests.get('https://www.promiseskept.com/achievement/overview/healthcare/').text

trump_soup = BeautifulSoup(trump_raw,'html.parser')

# %%
trump_groups = trump_soup.find_all('main',{'role':'main'})

# How many tags in total?
print(len(trump_groups))

# Inspect the first one
trump_groups[0]
# Out:
# 1
# <main role="main">
# <div class="container">
# <!-- Start Page Content -->
# <div class="page-intro vp-50">
# <h5>Making America Great Again</h5>
# <h1>Healthcare</h1>
# <h2 class="title-lines"><span></span>President Donald J. Trump Achievements</h2>
# </div>
# <div class="category-overview">
# <div class="main">
# <div class="share pb-40">
# <ul>
# <li><span>Share</span></li>
# <li><a class="facebook share icon" data-href="https://www.promiseskept.com/achievement/overview/healthcare" data-layout="button" href="https://www.facebook.com/sharer/sharer.php?u=https://www.promiseskept.com/achievement/overview/healthcare" target="_blank">Facebook</a></li>
# <li><a class="twitter icon share" href="https://twitter.com/home?status=https://www.promiseskept.com/achievement/overview/healthcare" target="_blank">Twitter</a></li>
# </ul>
# </div>
# <div class="acop-section">
# <div class="body">
# <p><strong>PROVIDING AMERICANS THE HEALTHCARE THEY NEED</strong></p>
# </div>
# ...

# %%
trump_groups[0].find_all('p')
# Out:
# [<p><strong>PROVIDING AMERICANS THE HEALTHCARE THEY NEED</strong></p>,
#  <p>The Department of Agriculture provided more than $1 billion in fiscal year 2017 to be used to improve access to health care services for 2.5 million people in rural communities.</p>,
#  <p>President Trump mobilized his entire Administration to address drug addiction and opioid abuse by directing the declaration of a Nationwide Public Health Emergency.</p>,
#  <p>President Trump signed an Executive order to reform the United States healthcare system to take the first steps to expand choices and alternatives to Obamacare plans and increase competition to bring down costs for consumers.</p>,
#  <p>President Trump concluded there is no appropriations for cost-sharing reduction (CSR) payments to insurance companies under Obamacare.</p>,
#  <p>President Trump repealed Obamacare’s individual mandate, which required individuals to purchase a health care plan they may not want or be able to afford.</p>,
# ...

# %%
trump_groups[0].find_all('li')
# Out:
# [<li><span>Share</span></li>,
#  <li><a class="facebook share icon" data-href="https://www.promiseskept.com/achievement/overview/healthcare" data-layout="button" href="https://www.facebook.com/sharer/sharer.php?u=https://www.promiseskept.com/achievement/overview/healthcare" target="_blank">Facebook</a></li>,
#  <li><a class="twitter icon share" href="https://twitter.com/home?status=https://www.promiseskept.com/achievement/overview/healthcare" target="_blank">Twitter</a></li>,
#  <li>President Trump created a bipartisan opioid commission and they issued 56 recommendations to help defeat the opioid crisis.</li>,
#  <li>In October 2017, President Trump directed The Department of Health And Human Services to declare the opioid crisis a public health emergency, allowing grant money to be used to combat abuse.   </li>,
# ...

# %%
trump_hc = []
    
for p in trump_groups[0].find_all('p'):
    trump_hc.append(p.text)
for p in trump_groups[0].find_all('li'):
    trump_hc.append(p.text)

# %%
trump_hc
# Out:
# ['PROVIDING AMERICANS THE HEALTHCARE THEY NEED',
#  'The Department of Agriculture provided more than $1 billion in fiscal year 2017 to be used to improve access to health care services for 2.5 million people in rural communities.',
#  'President Trump mobilized his entire Administration to address drug addiction and opioid abuse by directing the declaration of a Nationwide Public Health Emergency.',
#  'President Trump signed an Executive order to reform the United States healthcare system to take the first steps to expand choices and alternatives to Obamacare plans and increase competition to bring down costs for consumers.',
#  'President Trump concluded there is no appropriations for cost-sharing reduction (CSR) payments to insurance companies under Obamacare.',
#  'President Trump repealed Obamacare’s individual mandate, which required individuals to purchase a health care plan they may not want or be able to afford.',
# ...

# %%
set(trump_hc)
# Out:
# {'',
#  '\nEfforts are being realized on the side of the consumer as prices have gone down and drug competition has gone up.\xa0\n',
#  'August 2018 -\xa0HHS awarded $125 million in grants to 1,352 community health centers across all U.S. States, Territories, and the District of Columbia.',
#  'August 2018 -\xa0The FDA Helped To Facilitate Trade Between The U.S. and Foreign Trading Partners',
#  'CMS and the White House Office of American Innovation Rolled out a New Government Wide MyHealthEData Initiative to Increase Access to Health Data by Patients',
#  'CSR payments have no authority and are unlawful.',
#  'Efforts are being realized on the side of the consumer as prices have gone down and drug competition has gone up.\xa0',
#  'Enacted $31 billion in Obamacare tax relief.\xa0',
#  'Expanded access to Association Health Plans (AHPs) allowing small business to pool risk across states.',
#  'Facebook',
# ...

# %%
trump_hc[0].lower().split(' ')
# Out:
# ['providing', 'americans', 'the', 'healthcare', 'they', 'need']

# %%
trump_hc_list = []

# %%
for word in trump_hc[0].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[1].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[2].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[3].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[4].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[5].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[6].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[7].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[8].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[9].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[10].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[11].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[12].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[13].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[14].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[15].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[16].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[17].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[18].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[19].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[20].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[21].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[22].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[23].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[24].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[25].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[26].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[27].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[28].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[29].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[30].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[31].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[32].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[33].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[34].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[35].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[36].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[37].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[38].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[39].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)
for word in trump_hc[40].lower().split(' '):
    if word not in sw:
        trump_hc_list.append(word)

# %%
trump_hc_list
# Out:
# ['providing',
#  'americans',
#  'healthcare',
#  'need',
#  'department',
#  'agriculture',
#  'provided',
#  '$1',
#  'billion',
#  'fiscal',
#  'year',
#  '2017',
#  'used',
#  'improve',
#  'access',
#  'health',
#  'care',
#  'services',
#  '2.5',
#  'million',
#  'people',
#  'rural',
#  'communities.',
#  'providing',
#  'americans',
#  'healthcare',
#  'need',
#  'department',
#  'agriculture',
#  'provided',
#  '$1',
#  'billion',
#  'fiscal',
#  'year',
#  '2017',
#  'used',
#  'improve',
#  'access',
#  'health',
#  'care',
#  'services',
#  '2.5',
#  'million',
#  'people',
#  'rural',
#  'communities.',
#  'president',
#  'trump',
#  'mobilized',
#  'entire',
#  'administration',
#  'address',
#  'drug',
#  'addiction',
#  'opioid',
#  'abuse',
#  'directing',
#  'declaration',
#  'nationwide',
#  'public',
#  'health',
#  'emergency.',
#  'president',
#  'trump',
#  'signed',
#  'executive',
#  'order',
#  'reform',
#  'united',
#  'states',
#  'healthcare',
# ...

# %%
set(trump_hc_list)
# Out:
# {'',
#  '\nefforts',
#  '$1',
#  '$125',
#  '$31',
#  '$485',
#  '$50,000.\xa0',
#  '$60',
#  '$9',
#  '$900',
#  '(ahps)',
#  '(ahps),',
#  '(csr)',
#  '(interdict',
#  '-\xa0hhs',
#  '-\xa0the',
#  '1,352',
#  '12',
#  '2.5',
#  '2017',
#  '2017,',
#  '2018',
#  '250',
#  '56',
#  '80%',
#  '9',
#  'able',
#  'abuse',
#  'abuse.\xa0',
#  'abused',
#  'access',
#  'accessible,',
#  'across',
#  'act',
#  'act)',
#  'action',
#  'addiction',
#  'address',
#  'administration',
#  'affected',
#  'afford.',
#  'affordable',
#  'affordable,',
#  'agents',
#  'agreed',
#  'agriculture',
#  'aid',
#  'allow',
#  'allowing',
#  'allows',
#  'alternatives',
#  'american',
#  'americans',
#  'americans.',
#  'america’s',
#  'announced',
#  'announces',
#  'another',
#  'appropriated',
#  'appropriations',
#  'approved',
#  'april',
#  'assess',
#  'association',
#  'august',
#  'authority',
#  'awarded',
#  'bailout',
#  'billion',
#  'bipartisan',
#  'border.',
#  'bring',
#  'broken',
# ...

# %%
len(trump_hc_list)
# Out:
# 3398

# %%
len(set(trump_hc_list))
# Out:
# 347

# %%
intersection_warrentrump = s1 & s4

# %%
intersection_warrentrump
# Out:
# {'2017,',
#  'able',
#  'abuse',
#  'access',
#  'across',
#  'act',
#  'addiction',
#  'affordable',
#  'affordable,',
#  'allow',
#  'american',
#  'americans',
#  'billion',
#  'bring',
#  'business',
#  'care',
#  'centers',
#  'combat',
#  'communities.',
#  'community',
#  'companies',
#  'competition',
#  'consumer',
#  'costs',
#  'crisis',
#  'department',
#  'drug',
#  'drugs',
#  'emergency.',
#  'first',
#  'fund',
#  'funding',
#  'generic',
#  'health',
#  'help',
#  'hhs',
#  'human',
#  'improving',
#  'increase',
#  'insurance',
#  'less',
#  'limited',
#  'lower',
#  'manufacturers',
#  'medicaid',
#  'money',
#  'need',
#  'new',
#  'opioid',
#  'options',
#  'patients',
#  'plan',
#  'prices',
#  'primary',
#  'provide',
#  'provided',
#  'providing',
#  'public',
#  'required',
#  'right',
#  'risk',
#  'rural',
#  'services',
#  'state',
#  'states',
#  'support',
#  'system',
#  'system.',
#  'take',
#  'transparency',
#  'treatment',
#  'try',
#  'united',
# ...

# %%
len (intersection_warrentrump)
# Out:
# 78

# %%
union_warrentrump = s1|s4

# %%
union_warrentrump
# Out:
# {'',
#  '\nefforts',
#  '$1',
#  '$100',
#  '$125',
#  '$25',
#  '$31',
#  '$485',
#  '$50,000.\xa0',
#  '$60',
#  '$9',
#  '$900',
#  '(ahps)',
#  '(ahps),',
#  '(csr)',
#  '(interdict',
#  '--',
#  '-\xa0hhs',
#  '-\xa0the',
#  '1,352',
#  '12',
#  '15',
#  '15,000',
#  '1980s,',
#  '1990,',
#  '2.5',
#  '2017',
#  '2017,',
#  '2018',
#  '250',
#  '56',
#  '80%',
#  '9',
#  'able',
#  'abuse',
#  'abuse.\xa0',
#  'abused',
#  'access',
#  'accessible,',
#  'accountable',
#  'across',
#  'act',
#  'act)',
#  'act,',
#  'action',
#  'addiction',
#  'addictive',
#  'addition',
#  'address',
#  'adequate',
#  'administration',
#  'affected',
#  'afford',
#  'afford.',
#  'affordable',
#  'affordable,',
#  'afloat.\xa0',
#  'agents',
#  'aggressively',
#  'agreed',
#  'agriculture',
#  'aid',
#  'alike',
#  'all.',
#  'allow',
#  'allowing',
#  'allows',
#  'also',
#  'alternatives',
#  'american',
#  'americans',
#  'americans.',
#  'america’s',
#  'announced',
#  'announces',
# ...

# %%
len (union_warrentrump)
# Out:
# 651

# %%
len(s1 & s4)/len(s1 | s4)
# Out:
# 0.11981566820276497

# %%
intersection_bookertrump = s3 & s4

# %%
intersection_bookertrump
# Out:
# {'able',
#  'access',
#  'across',
#  'act',
#  'address',
#  'affordable',
#  'americans',
#  'americans.',
#  'broken',
#  'buy',
#  'care',
#  'certain',
#  'choices',
#  'community',
#  'cost-sharing',
#  'costs',
#  'department',
#  'directing',
#  'entire',
#  'funding',
#  'health',
#  'hhs',
#  'human',
#  'improving',
#  'increase',
#  'individual',
#  'individuals',
#  'labor',
#  'less',
#  'limited',
#  'medicaid',
#  'million',
#  'nearly',
#  'need',
#  'new',
#  'options',
#  'order',
#  'people',
#  'plan',
#  'promise',
#  'provide',
#  'providing',
#  'public',
#  'quality',
#  'required',
#  'right',
#  'services',
#  'states',
#  'states,',
#  'support',
#  'system',
#  'trump',
#  'want',
#  'would',
#  'yet'}

# %%
len (intersection_bookertrump)
# Out:
# 55

# %%
union_bookertrump = s3 | s4

# %%
union_bookertrump
# Out:
# {'',
#  '\nefforts',
#  '$1',
#  '$11.83',
#  '$125',
#  '$15',
#  '$19,100.',
#  '$2,000',
#  '$200,000',
#  '$25,000',
#  '$250,000.',
#  '$3,000',
#  '$31',
#  '$36,541',
#  '$485',
#  '$49,380',
#  '$50,000.\xa0',
#  '$60',
#  '$9',
#  '$900',
#  '(ahps)',
#  '(ahps),',
#  '(approximately',
#  '(csr)',
#  '(hhs)',
#  '(in',
#  '(interdict',
#  '(ltss).',
#  '(or',
#  '-\xa0hhs',
#  '-\xa0the',
#  '1',
#  '1,352',
#  '1.4',
#  '10',
#  '12',
#  '19',
#  '2.5',
#  '2016',
#  '2017',
#  '2017,',
#  '2018',
#  '2026.',
#  '2050,',
#  '222%',
#  '250',
#  '30',
#  '300%',
#  '37%',
#  '4',
#  '40%',
#  '42%',
#  '47.8',
#  '56',
#  '56%',
#  '6.3',
#  '600,000.',
#  '65',
#  '65-and-older',
#  '7',
#  '7.8',
#  '80%',
#  '85-and-older',
#  '87',
#  '87%',
#  '88',
#  '9',
#  'aarp,',
#  'able',
#  'abuse',
#  'abuse.\xa0',
#  'abused',
#  'access',
#  'accessible,',
#  'according',
#  'across',
#  'act',
#  'act)',
#  'act,',
#  'action',
#  'addiction',
#  'addition,',
#  'address',
# ...

# %%
len (union_bookertrump)
# Out:
# 687

# %%
len(s3 & s4)/len(s3 | s4)
# Out:
# 0.08005822416302766

# %%
intersection_bernietrump = s2 & s4

# %%
intersection_bernietrump
# Out:
# {'affordable',
#  'american',
#  'americans',
#  'buy',
#  'care',
#  'companies',
#  'costs',
#  'defeat',
#  'dollars',
#  'drug',
#  'drugs',
#  'executive',
#  'health',
#  'improve',
#  'insurance',
#  'less',
#  'lower',
#  'million',
#  'money',
#  'need',
#  'new',
#  'number',
#  'patients,',
#  'people',
#  'prescription',
#  'prices',
#  'provide',
#  'services',
#  'states.',
#  'united',
#  'year'}

# %%
len (intersection_bernietrump)
# Out:
# 31

# %%
union_bernietrump = s2 | s4

# %%
union_bernietrump
# Out:
# {'',
#  '\nefforts',
#  '$1',
#  '$125',
#  '$31',
#  '$485',
#  '$50,000.\xa0',
#  '$60',
#  '$9',
#  '$900',
#  '(ahps)',
#  '(ahps),',
#  '(csr)',
#  '(interdict',
#  '-\xa0hhs',
#  '-\xa0the',
#  '1,352',
#  '12',
#  '2.5',
#  '2017',
#  '2017,',
#  '2018',
#  '250',
#  '30',
#  '56',
#  '80%',
#  '9',
#  'able',
#  'abuse',
#  'abuse.\xa0',
#  'abused',
#  'access',
#  'accessible,',
#  'across',
#  'act',
#  'act)',
#  'act,',
#  'act.allow',
#  'act.cut',
#  'action',
#  'addiction',
#  'address',
#  'administration',
#  'administrative',
#  'affected',
#  'afford.',
#  'affordable',
#  'affordable,',
#  'agents',
#  'agreed',
#  'agriculture',
#  'aid',
#  'alleviate',
#  'allow',
#  'allowing',
#  'allows',
#  'alternatives',
#  'american',
#  'americans',
#  'americans.',
#  'america’s',
#  'announced',
#  'announces',
#  'another',
#  'appropriated',
#  'appropriations',
#  'approved',
#  'april',
#  'assess',
#  'association',
#  'august',
#  'authority',
#  'awarded',
# ...

# %%
len (union_bernietrump)
# Out:
# 460

# %%
len(s2 & s4)/len(s2 | s4)
# Out:
# 0.06739130434782609

# %% [markdown]
# ## Reading into it a little bit!

# %%
## WARREN:
# medicade / affordable care act
# medicare for all
# doctors get paid by medicare instead of fighting with insurance companies
# affordable drug manufacturing act
# lower cost of prescription drugs
# Behavioral Health Coverage Transparency Act - for mental health
# CARE Act - fight opiod crisis
# PROTECTING ACCESS TO HEALTH CARE IN RURAL COMMUNITIES

## BERNIE:
# Medicare for all
# medical bills = #1 cost of bankrupsy in the US...Warren talks about bankrupsy too.
# lower cost of prescription drugs - Medicare Drug Price Negotiation Act.
# buy low-cost prescription drugs from Canada and other industrialized 
    # ... countries with the Affordable and Safe Prescription Drug Importation Act. - warren talks about this too.
    # Prescription Drug Price Relief Act

## BOOKER:
# Focus on long term services and support 
# Talks about shortage of health care providers and how they are underpaid
# Medicare for all
# increase asset limits for long-term services and supports
# People can be taken care of at home, not have to go to hospital or alternative home
# Disability Integration Act
# fair wages, workforce training opportunities, and benefits like health care, 
    # ... retirement savings, and sick time, are part of all long-term services and supports programs
# Pay, train, and empower care workers as the essential workforce 
        # ... meaning those who are home care workers and those who work in nursing homes
# Rise Credit - paying family caregivers for the critical work they do
# financing

## TRUMP "ACHIEVMENTS" - from his website:
# talks about funding for people in rural communities 
# fightinh opdiod epidemic
# reform US healthcare system - alternatives to ObamaCare
# concluded there is no appropriations for cost-sharing reduction (CSR) payments 
    # ... to insurance companies under Obamacare.
#  lower the cost of prescription drugs for all Americans.
# access to more affordable healthcare - Short-Term Limited Duration plans to be extended up to 12 months.

## From this quick analysis, does seem like Warren woud have most in common wth Trump based on website content.?
