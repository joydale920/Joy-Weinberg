# %% [markdown]
# ## A little background
#
#
# ## https://nca2014.globalchange.gov/highlights/report-findings/extreme-weather
#
#
# ## "There has been a substantial increase in most measures of Atlantic hurricane activity since the early 1980s, the period during which high quality satellite data are available.,, These include measures of intensity, frequency, and duration as well as the number of strongest (Category 4 and 5) storms. The recent increases in activity are linked, in part, to higher sea surface temperatures in the region that Atlantic hurricanes form in and move through. Numerous factors have been shown to influence these local sea surface temperatures, including natural variability, human-induced emissions of heat-trapping gases, and particulate pollution. Quantifying the relative contributions of natural and human-caused factors is an active focus of research.
#
# ## Hurricane development, however, is influenced by more than just sea surface temperature. How hurricanes develop also depends on how the local atmosphere responds to changes in local sea surface temperatures, and this atmospheric response depends critically on the cause of the change., For example, the atmosphere responds differently when local sea surface temperatures increase due to a local decrease of particulate pollution that allows more sunlight through to warm the ocean, versus when sea surface temperatures increase more uniformly around the world due to increased amounts of human-caused heat-trapping gases.,,,
#
#
# ## By late this century, models, on average, project an increase in the number of the strongest (Category 4 and 5) hurricanes. Models also project greater rainfall rates in hurricanes in a warmer climate, with increases of about 20% averaged near the center of hurricanes."

# %%
#https://ourworldindata.org/co2-and-other-greenhouse-gas-emissions
#impact-of-emissions-on-atmospheric-concentrations

c02CSV = open("global-co-concentration-ppm.csv", "r")

c02CSV.readline() 
c02CSVList = c02CSV.read().splitlines()
c02CSV.close()

print(c02CSV)
# Out:
# <_io.TextIOWrapper name='global-co-concentration-ppm.csv' mode='r' encoding='UTF-8'>

# %%
c02CSV.close() 
for line in c02CSVList:
    #print(line+"\n")
    lineParts = line.split(",")
    #print(lineParts)
    
    # world concentration of C02 in ppm from 1959 - 2018
    print("Entity: "+lineParts[0] +", Year: "+lineParts[2]+". ppm: "+lineParts[3])
# Out:
# Entity: World, Year: 1959. ppm: 315.97
# Entity: World, Year: 1960. ppm: 316.91
# Entity: World, Year: 1961. ppm: 317.64
# Entity: World, Year: 1962. ppm: 318.45
# Entity: World, Year: 1963. ppm: 318.99
# Entity: World, Year: 1964. ppm: 319.62
# Entity: World, Year: 1965. ppm: 320.04
# Entity: World, Year: 1966. ppm: 321.38
# Entity: World, Year: 1967. ppm: 322.16
# Entity: World, Year: 1968. ppm: 323.04
# Entity: World, Year: 1969. ppm: 324.62
# Entity: World, Year: 1970. ppm: 325.68
# Entity: World, Year: 1971. ppm: 326.32
# Entity: World, Year: 1972. ppm: 327.45
# Entity: World, Year: 1973. ppm: 329.68
# Entity: World, Year: 1974. ppm: 330.18
# Entity: World, Year: 1975. ppm: 331.11
# Entity: World, Year: 1976. ppm: 332.04
# Entity: World, Year: 1977. ppm: 333.83
# Entity: World, Year: 1978. ppm: 335.4
# Entity: World, Year: 1979. ppm: 336.84
# Entity: World, Year: 1980. ppm: 338.75
# Entity: World, Year: 1981. ppm: 340.11
# Entity: World, Year: 1982. ppm: 341.45
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sb
# %matplotlib inline
pd.options.display.max_columns = 200

c02CSV = pd.read_csv("global-co-concentration-ppm.csv")
c02CSV.head()
# Out:
#   Entity      Code  Year  CO₂ concentration (parts per million)
# 0  World  OWID_WRL  1959                                 315.97
# 1  World  OWID_WRL  1960                                 316.91
# 2  World  OWID_WRL  1961                                 317.64
# 3  World  OWID_WRL  1962                                 318.45
# 4  World  OWID_WRL  1963                                 318.99

# %% [markdown]
# ## CO2 concentration in ppm descending from 2018

# %%
# can see that CO2 concentration over the years has risen steadily
# from 1959 - 2018 has risen 92.55 ppm
# 315 - 408 ppm
c02CSV.sort_values("CO₂ concentration (parts per million)",ascending=False).iloc[:,[2,3]]
# Out:
#     Year  CO₂ concentration (parts per million)
# 59  2018                                 408.52
# 58  2017                                 406.55
# 57  2016                                 404.24
# 56  2015                                 400.83
# 55  2014                                 398.65
# 54  2013                                 396.52
# 53  2012                                 393.85
# 52  2011                                 391.65
# 51  2010                                 389.90
# 50  2009                                 387.43
# 49  2008                                 385.60
# 48  2007                                 383.79
# 47  2006                                 381.90
# 46  2005                                 379.80
# 45  2004                                 377.52
# 44  2003                                 375.80
# 43  2002                                 373.28
# 42  2001                                 371.14
# 41  2000                                 369.55
# ...

# %% [markdown]
# ## Bar chart of CO2 rise from 1959-2018

# %%
sb.set_style("whitegrid")

sb.factorplot(x="Year",y="CO₂ concentration (parts per million)",data=c02CSV,kind="bar",aspect=5).set_xticklabels(rotation=90)
# Out:
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 8322 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 8322 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## Line plot of CO2 rise from 1959-2018

# %%
CO2Stats = c02CSV[["Year","CO₂ concentration (parts per million)"]].sort_values("CO₂ concentration (parts per million)",ascending=False)

sb.factorplot(x="Year",y="CO₂ concentration (parts per million)",data=CO2Stats,size=15).set_xticklabels(rotation=90)
# Out:
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 8322 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 8322 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
tempCSV = open("temperature-anomaly.csv", "r")

tempCSV.readline() 
tempCSVList = tempCSV.read().splitlines()
tempCSV.close()

print(tempCSV)
# Out:
# <_io.TextIOWrapper name='temperature-anomaly.csv' mode='r' encoding='UTF-8'>

# %%
# column 1 is the region
# column 2 is the year
# column 3 is the medium temp of that year
# column 4 is the upper limit
# column 5 is the lower limit

tempCSV.close()
for line in tempCSVList:
    #print(line+"\n")
    lineParts = line.split(",")
    #print(lineParts)
    
    # only care about global amounts and median temp
    # data from 1850 - 2017 about global median temps in celcius
    print("Entity: "+lineParts[0:169][0] +", Year: "+lineParts[2]+". Median: "+lineParts[3])
# Out:
# Entity: Global, Year: 1850. Median: -0.373
# Entity: Global, Year: 1851. Median: -0.218
# Entity: Global, Year: 1852. Median: -0.228
# Entity: Global, Year: 1853. Median: -0.269
# Entity: Global, Year: 1854. Median: -0.248
# Entity: Global, Year: 1855. Median: -0.272
# Entity: Global, Year: 1856. Median: -0.358
# Entity: Global, Year: 1857. Median: -0.461
# Entity: Global, Year: 1858. Median: -0.467
# Entity: Global, Year: 1859. Median: -0.284
# Entity: Global, Year: 1860. Median: -0.343
# Entity: Global, Year: 1861. Median: -0.407
# Entity: Global, Year: 1862. Median: -0.524
# Entity: Global, Year: 1863. Median: -0.278
# Entity: Global, Year: 1864. Median: -0.494
# Entity: Global, Year: 1865. Median: -0.279
# Entity: Global, Year: 1866. Median: -0.251
# Entity: Global, Year: 1867. Median: -0.321
# Entity: Global, Year: 1868. Median: -0.238
# Entity: Global, Year: 1869. Median: -0.262
# Entity: Global, Year: 1870. Median: -0.276
# Entity: Global, Year: 1871. Median: -0.335
# ...

# %%
# make a graph of this csv file!
# compare northern hem, southern hem, and tropics to Global as a whole on its own
# %matplotlib inline
pd.options.display.max_columns = 200

tempCSV = pd.read_csv("temperature-anomaly.csv")
tempCSV.head()
# Out:
#    Entity  Code  Year  Median (℃)  Upper (℃)  Lower (℃)
# 0  Global   NaN  1850      -0.373     -0.339     -0.425
# 1  Global   NaN  1851      -0.218     -0.184     -0.274
# 2  Global   NaN  1852      -0.228     -0.196     -0.280
# 3  Global   NaN  1853      -0.269     -0.239     -0.321
# 4  Global   NaN  1854      -0.248     -0.218     -0.301

# %% [markdown]
# ## Global Temp rise in degrees Celcius 1850-2017

# %%
# narrow it down to just global values
# highest to lowest and by year

tempCSV[["Entity","Year","Median (℃)"]].sort_values("Median (℃)",ascending=False).loc[tempCSV["Entity"]=="Global"]
# Out:
#      Entity  Year  Median (℃)
# 166  Global  2016       0.797
# 165  Global  2015       0.763
# 167  Global  2017       0.675
# 164  Global  2014       0.579
# 160  Global  2010       0.560
# 155  Global  2005       0.545
# 148  Global  1998       0.539
# 163  Global  2013       0.514
# 156  Global  2006       0.506
# 159  Global  2009       0.506
# 153  Global  2003       0.505
# 152  Global  2002       0.496
# 157  Global  2007       0.491
# 162  Global  2012       0.470
# 154  Global  2004       0.447
# 151  Global  2001       0.441
# 161  Global  2011       0.425
# 158  Global  2008       0.395
# 147  Global  1997       0.390
# 145  Global  1995       0.325
# 149  Global  1999       0.306
# 140  Global  1990       0.296
# 150  Global  2000       0.294
# 141  Global  1991       0.254
# 144  Global  1994       0.208
# 138  Global  1988       0.198
# 133  Global  1983       0.194
# 137  Global  1987       0.192
# 146  Global  1996       0.183
# 143  Global  1993       0.148
# ...

# %%
# we can see that Global average temp in celcius is rising. 

# %matplotlib inline
import seaborn as sb
# make a line plot of this data
globalStats = tempCSV[["Entity","Year","Median (℃)"]].sort_values("Median (℃)",ascending=False).loc[tempCSV["Entity"]=="Global"]

sb.factorplot(x="Year",y="Median (℃)",data=globalStats,size=15).set_xticklabels(rotation=90)
# Out:
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 8451 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 8451 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## Temp rise in Tropics

# %%
tempCSV[["Entity","Year","Median (℃)"]].sort_values("Median (℃)",ascending=False).loc[tempCSV["Entity"]=="Tropics"]
# Out:
#       Entity  Year  Median (℃)
# 670  Tropics  2016       0.763
# 669  Tropics  2015       0.737
# 652  Tropics  1998       0.564
# 671  Tropics  2017       0.559
# 663  Tropics  2009       0.541
# 664  Tropics  2010       0.535
# 668  Tropics  2014       0.516
# 657  Tropics  2003       0.507
# 659  Tropics  2005       0.487
# 656  Tropics  2002       0.469
# 660  Tropics  2006       0.449
# 658  Tropics  2004       0.430
# 667  Tropics  2013       0.404
# 651  Tropics  1997       0.368
# 661  Tropics  2007       0.365
# 641  Tropics  1987       0.358
# 655  Tropics  2001       0.350
# 666  Tropics  2012       0.346
# 649  Tropics  1995       0.285
# 662  Tropics  2008       0.274
# 623  Tropics  1969       0.246
# 665  Tropics  2011       0.243
# 595  Tropics  1941       0.241
# 637  Tropics  1983       0.222
# 532  Tropics  1878       0.215
# 644  Tropics  1990       0.206
# 645  Tropics  1991       0.206
# 642  Tropics  1988       0.205
# 650  Tropics  1996       0.193
# ...

# %%
globalStats = tempCSV[["Entity","Year","Median (℃)"]].sort_values("Median (℃)",ascending=False).loc[tempCSV["Entity"]=="Tropics"]

sb.factorplot(x="Year",y="Median (℃)",data=globalStats,size=15).set_xticklabels(rotation=90)
# Out:
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 8451 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 8451 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## Temp rise in Northern Hem

# %%
tempCSV[["Entity","Year","Median (℃)"]].sort_values("Median (℃)",ascending=False).loc[tempCSV["Entity"]=="Northern Hemisphere"]
# Out:
#                   Entity  Year  Median (℃)
# 334  Northern Hemisphere  2016       1.064
# 333  Northern Hemisphere  2015       1.033
# 335  Northern Hemisphere  2017       0.919
# 332  Northern Hemisphere  2014       0.779
# 328  Northern Hemisphere  2010       0.740
# 323  Northern Hemisphere  2005       0.724
# 325  Northern Hemisphere  2007       0.713
# 324  Northern Hemisphere  2006       0.676
# 331  Northern Hemisphere  2013       0.674
# 321  Northern Hemisphere  2003       0.642
# 330  Northern Hemisphere  2012       0.627
# 316  Northern Hemisphere  1998       0.614
# 322  Northern Hemisphere  2004       0.604
# 327  Northern Hemisphere  2009       0.594
# 320  Northern Hemisphere  2002       0.593
# 329  Northern Hemisphere  2011       0.575
# 326  Northern Hemisphere  2008       0.569
# 319  Northern Hemisphere  2001       0.558
# 313  Northern Hemisphere  1995       0.470
# 315  Northern Hemisphere  1997       0.456
# 308  Northern Hemisphere  1990       0.412
# ...

# %%
globalStats = tempCSV[["Entity","Year","Median (℃)"]].sort_values("Median (℃)",ascending=False).loc[tempCSV["Entity"]=="Northern Hemisphere"]

sb.factorplot(x="Year",y="Median (℃)",data=globalStats,size=15).set_xticklabels(rotation=90)
# Out:
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 8451 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 8451 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## Temp rise in Southern Hem

# %%
tempCSV[["Entity","Year","Median (℃)"]].sort_values("Median (℃)",ascending=False).loc[tempCSV["Entity"]=="Southern Hemisphere"]
# Out:
#                   Entity  Year  Median (℃)
# 502  Southern Hemisphere  2016       0.531
# 501  Southern Hemisphere  2015       0.497
# 484  Southern Hemisphere  1998       0.465
# 503  Southern Hemisphere  2017       0.433
# 495  Southern Hemisphere  2009       0.413
# 488  Southern Hemisphere  2002       0.398
# 500  Southern Hemisphere  2014       0.381
# 496  Southern Hemisphere  2010       0.379
# 489  Southern Hemisphere  2003       0.369
# 491  Southern Hemisphere  2005       0.367
# 499  Southern Hemisphere  2013       0.352
# 492  Southern Hemisphere  2006       0.336
# 487  Southern Hemisphere  2001       0.323
# 483  Southern Hemisphere  1997       0.323
# 498  Southern Hemisphere  2012       0.312
# 490  Southern Hemisphere  2004       0.289
# 497  Southern Hemisphere  2011       0.275
# 493  Southern Hemisphere  2007       0.270
# 473  Southern Hemisphere  1987       0.231
# 469  Southern Hemisphere  1983       0.220
# 494  Southern Hemisphere  2008       0.220
# ...

# %%
globalStats = tempCSV[["Entity","Year","Median (℃)"]].sort_values("Median (℃)",ascending=False).loc[tempCSV["Entity"]=="Southern Hemisphere"]

sb.factorplot(x="Year",y="Median (℃)",data=globalStats,size=15).set_xticklabels(rotation=90)
# Out:
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 8451 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 8451 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
tempcomparison = tempCSV.query("Entity == 'Global' or Entity == 'Tropics' or Entity == 'Northern Hemisphere' or Entity == 'Southern Hemisphere'")
tempcomparison
# Out:
#       Entity  Code  Year  Median (℃)  Upper (℃)  Lower (℃)
# 0     Global   NaN  1850      -0.373     -0.339     -0.425
# 1     Global   NaN  1851      -0.218     -0.184     -0.274
# 2     Global   NaN  1852      -0.228     -0.196     -0.280
# 3     Global   NaN  1853      -0.269     -0.239     -0.321
# 4     Global   NaN  1854      -0.248     -0.218     -0.301
# 5     Global   NaN  1855      -0.272     -0.241     -0.324
# 6     Global   NaN  1856      -0.358     -0.327     -0.413
# 7     Global   NaN  1857      -0.461     -0.431     -0.512
# 8     Global   NaN  1858      -0.467     -0.435     -0.521
# 9     Global   NaN  1859      -0.284     -0.249     -0.340
# 10    Global   NaN  1860      -0.343     -0.310     -0.405
# 11    Global   NaN  1861      -0.407     -0.356     -0.484
# 12    Global   NaN  1862      -0.524     -0.471     -0.597
# 13    Global   NaN  1863      -0.278     -0.226     -0.359
# 14    Global   NaN  1864      -0.494     -0.448     -0.564
# ...

# %% [markdown]
# ## Visual comparison Temp rise in all global regions

# %%
sb.factorplot(x="Year",y="Median (℃)", data=tempcomparison,hue="Entity",kind="point",size=15).set_xticklabels(rotation=90)

# %% [markdown]
# ## API:  Historical records of tropical storms.
# ## This API is a bit tricky to get a lot of information from because of its limits.
# ## The first request I make, I am only able to see ten tropical storm/hurricane tracks and the second request gives me at most 20

# %%
import requests

# Aeris Weather
# id = rh63Z79S23QsvcXR8Bsqr
# secret = o2K8xFP4T12B3TUkPlIVKQA3YXEOhMoEQ0T32f6A

# from 1992 - 2018
# I want to sort by year and see if the frequency of hurricanes has risen, fallen
# or stayed consistent over the years

stormHistory = requests.get("https://api.aerisapi.com/tropicalcyclones/archive/miami,fl?radius=1000miles&filter=track&query=year:1992:2018&client_id=rh63Z79S23QsvcXR8Bsqr&client_secret=o2K8xFP4T12B3TUkPlIVKQA3YXEOhMoEQ0T32f6A")
#stormHistory = requests.get("https://api.aerisapi.com/tropicalcyclones/archive/search?query=year:1851:2018&sort=maxwindspeed:-1&limit=1&client_id=rh63Z79S23QsvcXR8Bsqr&client_secret=o2K8xFP4T12B3TUkPlIVKQA3YXEOhMoEQ0T32f6A")

# %%
print(stormHistory)
type(stormHistory)
# Out:
# <Response [403]>
# requests.models.Response

# %% [markdown]
# ## Request to get tropical storms within 1000 miles of Miami
# ## Only allows me to see ten tracks!

# %%
import pprint

pprint.pprint(stormHistory.json())
stormHistoryInfo = stormHistory.json()
# Out:
# {'error': {'code': 'unauthorized_client',
#            'description': 'The client provided is not authorized to access the '
#                           'request.'},
#  'response': [],
#  'success': False}

# %%
stormHistoryInfo["response"] # this gets you the list that is the associated value to the key "response"
# each thing in the list is a dictionary and each dictionary has an ID
for storm in stormHistoryInfo["response"]:
    print(storm["id"]) # this prints each storm id
    # each storm has a profile key, whose value is a dictionary
    print(storm["profile"]["basins"]) # this gets the value associated with the "basins" key in the dictionary
    # associated with the key "profile" for each storm
    # you get the max storm cat, name, and year the same way
    
for storm in stormHistoryInfo["response"]:
    print(storm["id"]) 
    print(storm["profile"]["maxStormCat"])
    
for storm in stormHistoryInfo["response"]:
    print(storm["id"]) 
    print(storm["profile"]["name"])

# %% [markdown]
# ## Similarly, requested up to 20 tropical cyclones that occurred in the Atlantic basin over the past year...(2018)

# %%
stormHistory_2 = requests.get("https://api.aerisapi.com/tropicalcyclones/archive/search?filter=al&limit=20&client_id=rh63Z79S23QsvcXR8Bsqr&client_secret=o2K8xFP4T12B3TUkPlIVKQA3YXEOhMoEQ0T32f6A")

# %%
print(stormHistory_2)
type(stormHistory_2)
# Out:
# <Response [403]>
# requests.models.Response

# %%
pprint.pprint(stormHistory_2.json())
stormHistory_2Info = stormHistory_2.json()
# Out:
# {'error': {'code': 'unauthorized_client',
#            'description': 'The client provided is not authorized to access the '
#                           'request.'},
#  'response': [],
#  'success': False}

# %%
for storm in stormHistory_2Info["response"]:
    print(storm["id"]) # this prints each storm id
    # each storm has a profile key, whose value is a dictionary
    print(storm["profile"]["basins"]) # this gets the value associated with the "basins" key in the dictionary
    # associated with the key "profile" for each storm
    # you get the max storm cat, name, and year the same way
    
for storm in stormHistory_2Info["response"]:
    print(storm["id"]) 
    print(storm["profile"]["maxStormCat"])
    
for storm in stormHistory_2Info["response"]:
    print(storm["id"]) 
    print(storm["profile"]["name"])

# %% [markdown]
# ## In 2018 there were at least
# ## Seven Tropical Storms,
# ## Three Cat 1 Hurricanes,
# ## Two Cat 2 Hurricanes,
# ## One Cat 3 Hurricane,
# ## and Two Cat 4 Hurricanes
# ## However, this API request has a limit of only returning at most, 20 Hurricanes per request!

# %% [markdown]
# ## CSV: Tornado History in US

# %%
# CSV tornado records from 1957 - 2015

tornado_Tracks = open("Historical_Tornado_Tracks.csv", "r")

tornado_Tracks.readline() 
tornado_Tracks_List = tornado_Tracks.read().splitlines()
tornado_Tracks.close()

print(tornado_Tracks)
# Out:
# <_io.TextIOWrapper name='Historical_Tornado_Tracks.csv' mode='r' encoding='UTF-8'>

# %%
tornado_Tracks.close()
for line in tornado_Tracks_List:
    #print(line+"\n")
    lineParts = line.split(",")
    #print(lineParts)
    
    # only care about global amounts and median temp
    # data from 1850 - 2017 about global median temps in celcius
    print("Year: "+lineParts[2] +", State: "+lineParts[8]+". Magnitude: "+lineParts[11])
# Out:
# Year: 1957, State: TX. Magnitude: 2
# Year: 1957, State: TX. Magnitude: 0
# Year: 1957, State: TX. Magnitude: 0
# Year: 1957, State: TX. Magnitude: 2
# Year: 1957, State: TX. Magnitude: 0
# Year: 1957, State: TX. Magnitude: 1
# Year: 1957, State: MO. Magnitude: 1
# Year: 1957, State: IL. Magnitude: 2
# Year: 1957, State: IA. Magnitude: 0
# Year: 1957, State: MI. Magnitude: 1
# Year: 1957, State: TX. Magnitude: 0
# Year: 1957, State: TX. Magnitude: 0
# Year: 1957, State: NY. Magnitude: 1
# Year: 1957, State: NE. Magnitude: 4
# Year: 1957, State: TX. Magnitude: 1
# Year: 1957, State: NE. Magnitude: 3
# Year: 1957, State: OK. Magnitude: 0
# Year: 1957, State: OK. Magnitude: 2
# Year: 1957, State: OK. Magnitude: 1
# Year: 1957, State: OK. Magnitude: 1
# Year: 1957, State: AR. Magnitude: 3
# Year: 1957, State: TX. Magnitude: 0
# Year: 1957, State: TX. Magnitude: 2
# Year: 1957, State: TX. Magnitude: 2
# Year: 1957, State: TX. Magnitude: 3
# Year: 1957, State: TX. Magnitude: 2
# ...

# %%
# %matplotlib inline
pd.options.display.max_columns = 200

tornado_Tracks = pd.read_csv("Historical_Tornado_Tracks.csv")
tornado_Tracks.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    OBJECTID   om    yr  mo  dy        date      time  tz  st  stf  stn  mag  \
# 0      3001  234  1957   4  24  1957-04-24  15:45:00   3  TX   48   72    2
# 1      3002  235  1957   4  24  1957-04-24  16:00:00   3  TX   48   73    0
# 2      3003  236  1957   4  24  1957-04-24  16:12:00   3  TX   48   74    0
# 3      3004  237  1957   4  24  1957-04-24  16:20:00   3  TX   48   75    2
# 4      3005  238  1957   4  24  1957-04-24  16:30:00   3  TX   48   76    0
#
#    inj  fat  loss  closs   slat   slon   elat   elon  len  wid  fc  \
# 0    0    0   NaN      0  31.95 -96.68  32.00 -96.60  6.1  100   0
# 1    0    0   NaN      0  33.73 -96.67   0.00   0.00  0.1   10   1
# 2    0    0   NaN      0  30.90 -97.47   0.00   0.00  0.2   10   0
# ...

# %%
tornado_Tracks.sort_values("yr",ascending=False).iloc[:,[2,8,11]]
# Out:
#          yr  st  mag
# 60113  2015  IN    1
# 57937  2015  GA    1
# 57943  2015  MI    1
# 57942  2015  MI    0
# 57941  2015  OK    1
# 57940  2015  TX    0
# 57939  2015  OK    0
# 57938  2015  GA    1
# 57936  2015  GA    0
# 57928  2015  MS    0
# 57935  2015  GA    0
# 57934  2015  FL    1
# 57933  2015  GA    0
# 57932  2015  GA    0
# 57931  2015  MS    1
# 57930  2015  MS    0
# 57944  2015  MI    0
# 57945  2015  IA    0
# 57946  2015  IA    1
# 57947  2015  IA    1
# 57948  2015  IA    1
# 57949  2015  MO    0
# 57950  2015  IA    0
# 57951  2015  IA    1
# 57952  2015  IA    0
# 57953  2015  IA    1
# 57954  2015  IA    0
# 57955  2015  IA    0
# 57956  2015  IA    0
# 57957  2015  IA    1
# ...     ...  ..  ...
# 4106   1950  KS    2
# 4105   1950  FL    2
# 4104   1950  FL    1
# 4103   1950  TX    2
# 4124   1950  MS    3
# 4126   1950  GA    1
# 4149   1950  WI    4
# 4127   1950  TX    3
# 4148   1950  WI    2
# 4147   1950  WI    2
# 4146   1950  WI    1
# ...

# %% [markdown]
# ## Count number of tarnado occurances per year from 1957 - 2018

# %%
tornado_Tracks["yr"].head()
# Out:
# 0    1957
# 1    1957
# 2    1957
# 3    1957
# 4    1957
# Name: yr, dtype: int64

# %%
# sort index by years and number of occurances 

tornado_history = tornado_Tracks["yr"].value_counts().sort_index()

tornado_history
# Out:
# 1950     201
# 1951     260
# 1952     240
# 1953     421
# 1954     550
# 1955     591
# 1956     504
# 1957     858
# 1958     564
# 1959     604
# 1960     616
# 1961     697
# 1962     657
# 1963     463
# 1964     704
# 1965     897
# 1966     585
# 1967     927
# 1968     657
# 1969     608
# 1970     653
# 1971     889
# 1972     741
# 1973    1102
# 1974     945
# 1975     919
# 1976     834
# 1977     852
# 1978     789
# 1979     855
#         ...
# 1986     765
# 1987     656
# 1988     702
# 1989     856
# 1990    1133
# 1991    1132
# 1992    1297
# 1993    1172
# 1994    1082
# 1995    1237
# 1996    1173
# 1997    1148
# 1998    1424
# 1999    1339
# 2000    1075
# 2001    1215
# 2002     934
# 2003    1374
# 2004    1817
# 2005    1263
# 2006    1103
# 2007    1095
# 2008    1688
# 2009    1156
# 2010    1281
# 2011    1691
# 2012     938
# 2013     906
# 2014     886
# 2015    1177
# Name: yr, Length: 66, dtype: int64

# %% [markdown]
# ## From this graph we can see that the number of tornados per year are steadily increasing

# %%
historyPlot = tornado_history.plot()
historyPlot.set_xlabel("year") 
historyPlot.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ## My project focused on the relationship between anthropomorphic (human made) climate/environmental issues and hazerdous weather events.
# ## I am interested in this topic because of the current and previous research I help with, and also because I care deeply about our Earth's various and complex ecological systems.
# ## With more time, I would have really liked to dig deeper into how historical hurricane tracks have evolved over the years, and how these hazersous weather events impact marine life and human life as well.
# ## It would also be interesting to look into how other various hazerdous weather events have evolved over the years, which I started to do by analyzinf past tornado tracks.
# ## I hope you enjoyed my project and understand that with more time I would have loved to dig deeper into the plethora of weather and climate data out there.
